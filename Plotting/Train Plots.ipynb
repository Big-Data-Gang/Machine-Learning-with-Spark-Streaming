# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1000 Batch Size

# %%
df1000 = pd.read_csv('../src/performance/training/supervised-1000.csv')
df1000
# Out:
#       Batch No  SGD Accuracy  NB Accuracy  PA Accuracy
# 0            0         0.873        0.515        0.901
# 1            1         0.896        0.509        0.897
# 2            2         0.885        0.496        0.891
# 3            3         0.877        0.587        0.905
# 4            4         0.878        0.551        0.894
# ...        ...           ...          ...          ...
# 1134      1134         0.767        0.807        0.877
# 1135      1135         0.774        0.816        0.889
# 1136      1136         0.770        0.806        0.888
# 1137      1137         0.753        0.801        0.896
# 1138      1138         0.769        0.791        0.882
#
# [1139 rows x 4 columns]

# %%
df1000.plot(x="Batch No", y="SGD Accuracy", linewidth=0.5)
df1000.plot(x="Batch No", y="NB Accuracy", linewidth=0.5)
df1000.plot(x="Batch No", y="PA Accuracy", linewidth=0.5)
# Out:
# <AxesSubplot:xlabel='Batch No'>

# %% [markdown]
# # 2500 Batch Size

# %%
df2500 = pd.read_csv('../src/performance/training/supervised-2500.csv')
df2500
# Out:
#      Batch No  SGD Accuracy    SGD F1  SGD Precision  SGD Recall  NB Accuracy  \
# 0           0      0.840800  0.832209       0.864273    0.802439     0.508000
# 1           1      0.848000  0.859571       0.820748    0.902250     0.544400
# 2           2      0.867600  0.862826       0.868224    0.857496     0.725200
# 3           3      0.849200  0.854271       0.857254    0.851310     0.706800
# 4           4      0.853600  0.849877       0.846405    0.853377     0.877200
# ..        ...           ...       ...            ...         ...          ...
# 603       603      0.763600  0.772954       0.742984    0.805444     0.797200
# 604       604      0.753600  0.760498       0.723373    0.801639     0.799600
# 605       605      0.752400  0.766679       0.725392    0.812950     0.796000
# 606       606      0.757600  0.763651       0.727340    0.803777     0.814400
# 607       607      0.751501  0.756375       0.722639    0.793416     0.798319
#
# ...

# %%
df2500.columns
# Out:
# Index(['Batch No', 'SGD Accuracy', 'SGD F1', 'SGD Precision', 'SGD Recall',
#        'NB Accuracy', 'NB F1', 'NB Precision', 'NB Recall', 'PA Accuracy',
#        'PA F1', 'PA Precision', 'PA Recall', 'Unnamed: 13'],
#       dtype='object')

# %%
plt.plot(df2500['Batch No'], df2500['SGD Accuracy'] * 100, label='SGD', linewidth=0.75)
plt.plot(df2500['Batch No'], df2500['NB Accuracy'] * 100, label='NB', linewidth=0.75)
plt.plot(df2500['Batch No'], df2500['PA Accuracy'] * 100, label='PA', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('Accuracy in %')
plt.title('Training Accuracy % for Batch Size 2500')
plt.legend()
plt.figure()

# %%
plt.plot(df2500['Batch No'], df2500['SGD F1'] * 100, label='SGD', linewidth=0.75)
plt.plot(df2500['Batch No'], df2500['NB F1'] * 100, label='NB', linewidth=0.75)
plt.plot(df2500['Batch No'], df2500['PA F1'] * 100, label='PA', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('F1 in %')
plt.title('Training F1 % for Batch Size 2500')
plt.legend()
plt.figure()

# %%
plt.plot(df2500['Batch No'], df2500['SGD Precision'] * 100, label='SGD', linewidth=0.75)
plt.plot(df2500['Batch No'], df2500['NB Precision'] * 100, label='NB', linewidth=0.75)
plt.plot(df2500['Batch No'], df2500['PA Precision'] * 100, label='PA', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('Precision in %')
plt.title('Training Precision % for Batch Size 2500')
plt.legend()
plt.figure()

# %%
plt.plot(df2500['Batch No'], df2500['SGD Recall'] * 100, label='SGD', linewidth=0.75)
plt.plot(df2500['Batch No'], df2500['NB Recall'] * 100, label='NB', linewidth=0.75)
plt.plot(df2500['Batch No'], df2500['PA Recall'] * 100, label='PA', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('Recall in %')
plt.title('Training Recall % for Batch Size 2500')
plt.legend()
plt.figure()

# %%
plt.plot(df2500['Batch No'], df2500['SGD F1'] * 100, label='F1', linewidth=0.75)
plt.plot(df2500['Batch No'], df2500['SGD Precision'] * 100, label='Precision', linewidth=0.75)
plt.plot(df2500['Batch No'], df2500['SGD Recall'] * 100, label='Recall', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('in %')
plt.title('Training SGD Evaluation for Batch Size 2500')
plt.legend()
plt.figure()

# %%
plt.plot(df2500['Batch No'], df2500['NB F1'] * 100, label='F1', linewidth=0.75)
plt.plot(df2500['Batch No'], df2500['NB Precision'] * 100, label='Precision', linewidth=0.75)
plt.plot(df2500['Batch No'], df2500['NB Recall'] * 100, label='Recall', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('in %')
plt.title('Training NB Evaluation for Batch Size 2500')
plt.legend()
plt.figure()

# %%
plt.plot(df2500['Batch No'], df2500['PA F1'] * 100, label='F1', linewidth=0.75)
plt.plot(df2500['Batch No'], df2500['PA Precision'] * 100, label='Precision', linewidth=0.75)
plt.plot(df2500['Batch No'], df2500['PA Recall'] * 100, label='Recall', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('in %')
plt.title('Training PA Evaluation for Batch Size 2500')
plt.legend()
plt.figure()

# %% [markdown]
# # 5000 Batch Size

# %%
df5000 = pd.read_csv('../src/performance/training/supervised-5000.csv')
df5000
# Out:
#      Batch No  SGD Accuracy    SGD F1  SGD Precision  SGD Recall  NB Accuracy  \
# 0           0      0.817000  0.816376       0.825487    0.807463     0.536800
# 1           1      0.830600  0.821647       0.872150    0.776672     0.695400
# 2           2      0.823200  0.819959       0.819625    0.820293     0.867200
# 3           3      0.817400  0.818019       0.816554    0.819489     0.862600
# 4           4      0.814600  0.814563       0.814074    0.815052     0.861200
# ..        ...           ...       ...            ...         ...          ...
# 299       299      0.753000  0.764448       0.726350    0.806763     0.787800
# 300       300      0.753600  0.772189       0.742004    0.804934     0.788400
# 301       301      0.762200  0.775956       0.739052    0.816739     0.792800
# 302       302      0.753200  0.764054       0.724175    0.808580     0.797400
# 303       303      0.753951  0.759578       0.724189    0.798603     0.806161
#
# ...

# %%
plt.plot(df5000['Batch No'], df5000['SGD Accuracy'] * 100, label='SGD', linewidth=0.75)
plt.plot(df5000['Batch No'], df5000['NB Accuracy'] * 100, label='NB', linewidth=0.75)
plt.plot(df5000['Batch No'], df5000['PA Accuracy'] * 100, label='PA', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('Accuracy in %')
plt.title('Training Accuracy % for Batch Size 5000')
plt.legend()
plt.figure()

# %%
plt.plot(df5000['Batch No'], df5000['SGD F1'] * 100, label='SGD', linewidth=0.75)
plt.plot(df5000['Batch No'], df5000['NB F1'] * 100, label='NB', linewidth=0.75)
plt.plot(df5000['Batch No'], df5000['PA F1'] * 100, label='PA', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('F1 in %')
plt.title('Training F1 % for Batch Size 5000')
plt.legend()
plt.figure()

# %%
plt.plot(df5000['Batch No'], df5000['SGD Precision'] * 100, label='SGD', linewidth=0.75)
plt.plot(df5000['Batch No'], df5000['NB Precision'] * 100, label='NB', linewidth=0.75)
plt.plot(df5000['Batch No'], df5000['PA Precision'] * 100, label='PA', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('Precision in %')
plt.title('Training Precision % for Batch Size 5000')
plt.legend()
plt.figure()

# %%
plt.plot(df5000['Batch No'], df5000['SGD Recall'] * 100, label='SGD', linewidth=0.75)
plt.plot(df5000['Batch No'], df5000['NB Recall'] * 100, label='NB', linewidth=0.75)
plt.plot(df5000['Batch No'], df5000['PA Recall'] * 100, label='PA', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('Recall in %')
plt.title('Training Recall % for Batch Size 5000')
plt.legend()
plt.figure()

# %%
plt.plot(df5000['Batch No'], df5000['SGD F1'] * 100, label='F1', linewidth=0.75)
plt.plot(df5000['Batch No'], df5000['SGD Precision'] * 100, label='Precision', linewidth=0.75)
plt.plot(df5000['Batch No'], df5000['SGD Recall'] * 100, label='Recall', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('in %')
plt.title('Training SGD Evaluation for Batch Size 5000')
plt.legend()
plt.figure()

# %%
plt.plot(df5000['Batch No'], df5000['NB F1'] * 100, label='F1', linewidth=0.75)
plt.plot(df5000['Batch No'], df5000['NB Precision'] * 100, label='Precision', linewidth=0.75)
plt.plot(df5000['Batch No'], df5000['NB Recall'] * 100, label='Recall', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('in %')
plt.title('Training NB Evaluation for Batch Size 5000')
plt.legend()
plt.figure()

# %%
plt.plot(df5000['Batch No'], df5000['PA F1'] * 100, label='F1', linewidth=0.75)
plt.plot(df5000['Batch No'], df5000['PA Precision'] * 100, label='Precision', linewidth=0.75)
plt.plot(df5000['Batch No'], df5000['PA Recall'] * 100, label='Recall', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('in %')
plt.title('Training PA Evaluation for Batch Size 5000')
plt.legend()
plt.figure()

# %% [markdown]
# # 10000 Batch Size

# %%
df10000 = pd.read_csv('../src/performance/training/supervised-10000.csv')
df10000
# Out:
#      Batch No  SGD Accuracy    SGD F1  SGD Precision  SGD Recall  NB Accuracy  \
# 0           0      0.799300  0.805051       0.787234    0.823693      0.69490
# 1           1      0.806700  0.811910       0.784358    0.841468      0.86280
# 2           2      0.801300  0.809071       0.786328    0.833168      0.84820
# 3           3      0.791300  0.799731       0.774391    0.826786      0.83840
# 4           4      0.773600  0.776108       0.769110    0.783234      0.82700
# ..        ...           ...       ...            ...         ...          ...
# 147       147      0.759500  0.770625       0.735482    0.809295      0.80010
# 148       148      0.756700  0.770363       0.740250    0.803030      0.79190
# 149       149      0.756300  0.768764       0.731888    0.809552      0.79270
# 150       150      0.758500  0.774278       0.741762    0.809775      0.79060
# 151       151      0.753775  0.761942       0.724531    0.803426      0.80198
#
# ...

# %%
plt.plot(df10000['Batch No'], df10000['SGD Accuracy'] * 100, label='SGD', linewidth=0.75)
plt.plot(df10000['Batch No'], df10000['NB Accuracy'] * 100, label='NB', linewidth=0.75)
plt.plot(df10000['Batch No'], df10000['PA Accuracy'] * 100, label='PA', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('Accuracy in %')
plt.title('Training Accuracy % for Batch Size 10000')
plt.legend()
plt.figure()

# %%
plt.plot(df10000['Batch No'], df10000['SGD F1'] * 100, label='SGD', linewidth=0.75)
plt.plot(df10000['Batch No'], df10000['NB F1'] * 100, label='NB', linewidth=0.75)
plt.plot(df10000['Batch No'], df10000['PA F1'] * 100, label='PA', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('F1 in %')
plt.title('Training F1 % for Batch Size 10000')
plt.legend()
plt.figure()

# %%
plt.plot(df10000['Batch No'], df10000['SGD Precision'] * 100, label='SGD', linewidth=0.75)
plt.plot(df10000['Batch No'], df10000['NB Precision'] * 100, label='NB', linewidth=0.75)
plt.plot(df10000['Batch No'], df10000['PA Precision'] * 100, label='PA', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('Precision in %')
plt.title('Training Precision % for Batch Size 10000')
plt.legend()
plt.figure()

# %%
plt.plot(df10000['Batch No'], df10000['SGD Recall'] * 100, label='SGD', linewidth=0.75)
plt.plot(df10000['Batch No'], df10000['NB Recall'] * 100, label='NB', linewidth=0.75)
plt.plot(df10000['Batch No'], df10000['PA Recall'] * 100, label='PA', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('Recall in %')
plt.title('Training Recall % for Batch Size 10000')
plt.legend()
plt.figure()

# %%
plt.plot(df10000['Batch No'], df10000['SGD F1'] * 100, label='F1', linewidth=0.75)
plt.plot(df10000['Batch No'], df10000['SGD Precision'] * 100, label='Precision', linewidth=0.75)
plt.plot(df10000['Batch No'], df10000['SGD Recall'] * 100, label='Recall', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('in %')
plt.title('Training SGD Evaluation for Batch Size 10000')
plt.legend()
plt.figure()

# %%
plt.plot(df10000['Batch No'], df10000['NB F1'] * 100, label='F1', linewidth=0.75)
plt.plot(df10000['Batch No'], df10000['NB Precision'] * 100, label='Precision', linewidth=0.75)
plt.plot(df10000['Batch No'], df10000['NB Recall'] * 100, label='Recall', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('in %')
plt.title('Training NB Evaluation for Batch Size 10000')
plt.legend()
plt.figure()

# %%
plt.plot(df10000['Batch No'], df10000['PA F1'] * 100, label='F1', linewidth=0.75)
plt.plot(df10000['Batch No'], df10000['PA Precision'] * 100, label='Precision', linewidth=0.75)
plt.plot(df10000['Batch No'], df10000['PA Recall'] * 100, label='Recall', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('in %')
plt.title('Training PA Evaluation for Batch Size 10000')
plt.legend()
plt.figure()

# %% [markdown]
# # 20000 Batch Size

# %%
df20000 = pd.read_csv('../src/performance/training/supervised-20000.csv')
df20000
# Out:
#     Batch No  SGD Accuracy    SGD F1  SGD Precision  SGD Recall  NB Accuracy  \
# 0          0      0.788250  0.791636       0.778348    0.805386      0.86215
# 1          1      0.782900  0.797971       0.752259    0.849599      0.84085
# 2          2      0.769800  0.776851       0.755895    0.799003      0.83270
# 3          3      0.770900  0.775788       0.752516    0.800545      0.83220
# 4          4      0.776050  0.775747       0.774390    0.777109      0.83215
# ..       ...           ...       ...            ...         ...          ...
# 71        71      0.756350  0.768228       0.735586    0.803902      0.79695
# 72        72      0.751950  0.761456       0.733488    0.791642      0.79565
# 73        73      0.758050  0.768679       0.734649    0.806015      0.79765
# 74        74      0.756950  0.769675       0.737090    0.805275      0.79225
# 75        75      0.755438  0.766417       0.734799    0.800878      0.79639
#
# ...

# %%
plt.plot(df20000['Batch No'], df20000['SGD Accuracy'] * 100, label='SGD', linewidth=0.75)
plt.plot(df20000['Batch No'], df20000['NB Accuracy'] * 100, label='NB', linewidth=0.75)
plt.plot(df20000['Batch No'], df20000['PA Accuracy'] * 100, label='PA', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('Accuracy in %')
plt.title('Training Accuracy % for Batch Size 20000')
plt.legend()
plt.figure()

# %%
plt.plot(df20000['Batch No'], df20000['SGD F1'] * 100, label='SGD', linewidth=0.75)
plt.plot(df20000['Batch No'], df20000['NB F1'] * 100, label='NB', linewidth=0.75)
plt.plot(df20000['Batch No'], df20000['PA F1'] * 100, label='PA', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('F1 in %')
plt.title('Training F1 % for Batch Size 20000')
plt.legend()
plt.figure()

# %%
plt.plot(df20000['Batch No'], df20000['SGD Precision'] * 100, label='SGD', linewidth=0.75)
plt.plot(df20000['Batch No'], df20000['NB Precision'] * 100, label='NB', linewidth=0.75)
plt.plot(df20000['Batch No'], df20000['PA Precision'] * 100, label='PA', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('Precision in %')
plt.title('Training Precision % for Batch Size 20000')
plt.legend()
plt.figure()

# %%
plt.plot(df20000['Batch No'], df20000['SGD Recall'] * 100, label='SGD', linewidth=0.75)
plt.plot(df20000['Batch No'], df20000['NB Recall'] * 100, label='NB', linewidth=0.75)
plt.plot(df20000['Batch No'], df20000['PA Recall'] * 100, label='PA', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('Recall in %')
plt.title('Training Recall % for Batch Size 20000')
plt.legend()
plt.figure()

# %%
plt.plot(df20000['Batch No'], df20000['SGD F1'] * 100, label='F1', linewidth=0.75)
plt.plot(df20000['Batch No'], df20000['SGD Precision'] * 100, label='Precision', linewidth=0.75)
plt.plot(df20000['Batch No'], df20000['SGD Recall'] * 100, label='Recall', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('in %')
plt.title('Training SGD Evaluation for Batch Size 20000')
plt.legend()
plt.figure()

# %%
plt.plot(df20000['Batch No'], df20000['NB F1'] * 100, label='F1', linewidth=0.75)
plt.plot(df20000['Batch No'], df20000['NB Precision'] * 100, label='Precision', linewidth=0.75)
plt.plot(df20000['Batch No'], df20000['NB Recall'] * 100, label='Recall', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('in %')
plt.title('Training NB Evaluation for Batch Size 20000')
plt.legend()
plt.figure()

# %%
plt.plot(df20000['Batch No'], df20000['PA F1'] * 100, label='F1', linewidth=0.75)
plt.plot(df20000['Batch No'], df20000['PA Precision'] * 100, label='Precision', linewidth=0.75)
plt.plot(df20000['Batch No'], df20000['PA Recall'] * 100, label='Recall', linewidth=0.75)
plt.xlabel('Batch No')
plt.ylabel('in %')
plt.title('Training PA Evaluation for Batch Size 20000')
plt.legend()
plt.figure()

# %% [markdown]
# 1000 Batch size

# %%
clustering1000 = pd.read_csv('../src/performance/training/unsupervised-1000.csv')
clustering1000
# Out:
#       Batch No         SSE  Silhouette Score  Accuracy
# 0            0  975.991934          0.003960     0.476
# 1            1  979.262563          0.003661     0.488
# 2            2  976.374342          0.002029     0.503
# 3            3  978.455519          0.003519     0.512
# 4            4  979.137802          0.002589     0.517
# ...        ...         ...               ...       ...
# 1133      1133  975.183401          0.004562     0.514
# 1134      1134  981.018697          0.001791     0.481
# 1135      1135  978.133782          0.003364     0.507
# 1136      1136  973.284461          0.004336     0.482
# 1137      1137  974.971559          0.003288     0.503
#
# [1138 rows x 4 columns]

# %%
clustering1000.plot(x="Batch No", y="SSE", linewidth=0.5)
clustering1000.plot(x="Batch No", y="Silhouette Score", linewidth=0.5)
clustering1000.plot(x="Batch No", y="Accuracy", linewidth=0.5)
# Out:
# <AxesSubplot:xlabel='Batch No'>

# %% [markdown]
# 2500 Batch Size

# %%
clustering2500 = pd.read_csv('../src/performance/training/unsupervised-2500.csv')
clustering2500.plot(x="Batch No", y="SSE", linewidth=0.5)
clustering2500.plot(x="Batch No", y="Silhouette Score", linewidth=0.5)
clustering2500.plot(x="Batch No", y="Accuracy", linewidth=0.5)
# Out:
# <AxesSubplot:xlabel='Batch No'>

# %% [markdown]
# 5000 Batch Size

# %%
clustering5000 = pd.read_csv('../src/performance/training/unsupervised-5000.csv')
clustering5000.plot(x="Batch No", y="SSE", linewidth=0.5)
clustering5000.plot(x="Batch No", y="Silhouette Score", linewidth=0.5)
clustering5000.plot(x="Batch No", y="Accuracy", linewidth=0.5)
# Out:
# <AxesSubplot:xlabel='Batch No'>

# %% [markdown]
# 2500 vs 5000 Batch Size

# %%
ax = clustering2500[['Batch No', 'Silhouette Score']].set_index('Batch No').plot()
# set_size(7.5, 7.5, ax)
clustering5000[['Batch No', 'Silhouette Score']].set_index('Batch No').plot(ax=ax, linewidth=0.5)
# Out:
# <AxesSubplot:xlabel='Batch No'>

# %%
ax = clustering2500[['Batch No', 'SSE']].set_index('Batch No').plot()
# set_size(7.5, 7.5, ax)
clustering5000[['Batch No', 'SSE']].set_index('Batch No').plot(ax=ax, linewidth=0.5)
# Out:
# <AxesSubplot:xlabel='Batch No'>

# %%
ax = clustering2500[['Batch No', 'Accuracy']].set_index('Batch No').plot()
# set_size(7.5, 7.5, ax)
clustering5000[['Batch No', 'Accuracy']].set_index('Batch No').plot(ax=ax, linewidth=0.5)
# Out:
# <AxesSubplot:xlabel='Batch No'>
