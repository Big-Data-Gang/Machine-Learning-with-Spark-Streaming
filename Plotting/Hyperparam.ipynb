# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../src/performance/hyperparam/supervised-run1.csv')
df
# Out:
#      Batch No  SGD L1 Accuracy  SGD L2 Accuracy  NB alpha 1 Accuracy  \
# 0           0         0.778700         0.798200              0.69490
# 1           1         0.774200         0.807000              0.86280
# 2           2         0.777300         0.798700              0.84820
# 3           3         0.768300         0.793000              0.83840
# 4           4         0.753100         0.775000              0.82700
# ..        ...              ...              ...                  ...
# 147       147         0.750300         0.759900              0.80010
# 148       148         0.743900         0.756600              0.79190
# 149       149         0.744700         0.756600              0.79270
# 150       150         0.746700         0.758000              0.79060
# 151       151         0.744874         0.753475              0.80198
#
#      NB alpha 2 Accuracy  NB alpha 4 Accuracy  PA C 1 Accuracy  \
# 0               0.532700             0.503200         0.821600
# ...

# %%
plt.plot(df['SGD L1 Accuracy'], color='r', label='L1 penalty')
plt.plot(df['SGD L2 Accuracy'], color='b', label='L2 penalty')
plt.legend()
plt.title('SGD(SVM) - Penalty Function tuning')
plt.xlabel('Batch No.')
plt.ylabel('Accuracy')
plt.show()

# %%
plt.plot(df['NB alpha 1 Accuracy'], color='r', label='alpha=1')
plt.plot(df['NB alpha 2 Accuracy'], color='b', label='alpha=2')
plt.plot(df['NB alpha 4 Accuracy'], color='g', label='alpha=4')
plt.legend()
plt.title('Naive Bayes - Smoothing Factor tuning')
plt.xlabel('Batch No.')
plt.ylabel('Accuracy')
plt.show()

# %%
plt.plot(df['PA C 1 Accuracy'], color='r', label='C=1')
plt.plot(df['PA C 5 Accuracy'], color='b', label='C=5')
plt.legend()
plt.title('Passive Agressive - Regularization term tuning')
plt.xlabel('Batch No.')
plt.ylabel('Accuracy')
plt.show()
