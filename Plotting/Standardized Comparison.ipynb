# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Standard Scores 2500

# %%
df2500 = pd.read_csv('../src/performance/testing/standard-scores-2500.csv')

# %%
df2500
# Out:
#     Batch  NB Score     NB F1  NB Precision  NB Recall  PA Score     PA F1  \
# 0       0     0.761  0.759799      0.757515   0.762097     0.715  0.725698
# 1       1     0.755  0.751269      0.741483   0.761317     0.721  0.716751
# 2       2     0.761  0.766829      0.769080   0.764591     0.749  0.756547
# 3       3     0.753  0.747185      0.766807   0.728543     0.727  0.726179
# 4       4     0.786  0.775210      0.778481   0.771967     0.769  0.767839
# ..    ...       ...       ...           ...        ...       ...       ...
# 75     75     0.766  0.760246      0.760246   0.760246     0.717  0.718967
# 76     76     0.780  0.781746      0.791165   0.772549     0.770  0.777132
# 77     77     0.751  0.752731      0.764113   0.741683     0.725  0.733269
# 78     78     0.747  0.756497      0.747148   0.766082     0.728  0.744361
# 79     79     0.741  0.745329      0.749012   0.741683     0.723  0.730807
#
#     PA Precision  PA Recall  SGD Score    SGD F1  SGD Precision  SGD Recall
# 0       0.694291   0.760081      0.751  0.759420       0.729128    0.792339
# 1       0.707415   0.726337      0.742  0.748047       0.711896    0.788066
# 2       0.754352   0.758755      0.755  0.769086       0.745887    0.793774
# 3       0.729839   0.722555      0.748  0.758621       0.729282    0.790419
# 4       0.738878   0.799163      0.774  0.774900       0.739544    0.813808
# ..           ...        ...        ...       ...            ...         ...
# 75      0.697495   0.741803      0.741  0.742289       0.721470    0.764344
# 76      0.768199   0.786275      0.796  0.805344       0.784387    0.827451
# 77      0.726923   0.739726      0.742  0.755682       0.732110    0.780822
# 78      0.718693   0.771930      0.734  0.755064       0.715532    0.799220
# 79      0.725869   0.735812      0.740  0.754717       0.728597    0.782779
#
# [80 rows x 13 columns]

# %% [markdown]
# # Standard Scores 5000

# %%
df5000 = pd.read_csv('../src/performance/testing/standard-scores-5000.csv')

# %%
df5000
# Out:
#     Batch  NB Score     NB F1  NB Precision  NB Recall  PA Score     PA F1  \
# 0       0     0.761  0.759799      0.757515   0.762097     0.716  0.724272
# 1       1     0.755  0.751269      0.741483   0.761317     0.745  0.747275
# 2       2     0.761  0.766829      0.769080   0.764591     0.747  0.760190
# 3       3     0.753  0.747185      0.766807   0.728543     0.728  0.730693
# 4       4     0.786  0.775210      0.778481   0.771967     0.762  0.764822
# ..    ...       ...       ...           ...        ...       ...       ...
# 75     75     0.766  0.760246      0.760246   0.760246     0.734  0.742248
# 76     76     0.780  0.781746      0.791165   0.772549     0.761  0.772164
# 77     77     0.751  0.752731      0.764113   0.741683     0.733  0.746919
# 78     78     0.747  0.756497      0.747148   0.766082     0.733  0.751628
# 79     79     0.741  0.745329      0.749012   0.741683     0.745  0.758294
#
#     PA Precision  PA Recall  SGD Score    SGD F1  SGD Precision  SGD Recall
# 0       0.698502   0.752016      0.752  0.760155       0.730483    0.792339
# 1       0.720841   0.775720      0.741  0.747317       0.710575    0.788066
# 2       0.741220   0.780156      0.757  0.770538       0.748624    0.793774
# 3       0.724951   0.736527      0.748  0.758621       0.729282    0.790419
# 4       0.724719   0.809623      0.774  0.774900       0.739544    0.813808
# ..           ...        ...        ...       ...            ...         ...
# 75      0.704044   0.784836      0.739  0.740299       0.719536    0.762295
# 76      0.751391   0.794118      0.796  0.805714       0.783333    0.829412
# 77      0.724265   0.771037      0.742  0.755682       0.732110    0.780822
# 78      0.718861   0.787524      0.734  0.755515       0.714783    0.801170
# 79      0.735294   0.782779      0.741  0.755430       0.729927    0.782779
#
# [80 rows x 13 columns]

# %% [markdown]
# # Standard Scores 10000

# %%
df10000 = pd.read_csv('../src/performance/testing/standard-scores-10000.csv')

# %%
df10000
# Out:
#     Batch  NB Score     NB F1  NB Precision  NB Recall  PA Score     PA F1  \
# 0       0     0.761  0.759799      0.757515   0.762097     0.716  0.704167
# 1       1     0.755  0.751269      0.741483   0.761317     0.723  0.697928
# 2       2     0.761  0.766829      0.769080   0.764591     0.735  0.730417
# 3       3     0.753  0.747185      0.766807   0.728543     0.720  0.703390
# 4       4     0.786  0.775210      0.778481   0.771967     0.756  0.734205
# ..    ...       ...       ...           ...        ...       ...       ...
# 75     75     0.766  0.760246      0.760246   0.760246     0.737  0.715676
# 76     76     0.780  0.781746      0.791165   0.772549     0.765  0.754953
# 77     77     0.751  0.752731      0.764113   0.741683     0.709  0.698446
# 78     78     0.747  0.756497      0.747148   0.766082     0.723  0.720484
# 79     79     0.741  0.745329      0.749012   0.741683     0.711  0.699272
#
#     PA Precision  PA Recall  SGD Score    SGD F1  SGD Precision  SGD Recall
# 0       0.728448   0.681452      0.753  0.760891       0.731844    0.792339
# 1       0.742459   0.658436      0.742  0.748538       0.711111    0.790123
# 2       0.765458   0.698444      0.757  0.770971       0.747715    0.795720
# 3       0.749436   0.662675      0.748  0.759082       0.728440    0.792415
# 4       0.765909   0.705021      0.773  0.774129       0.738140    0.813808
# ..           ...        ...        ...       ...            ...         ...
# 75      0.757437   0.678279      0.741  0.742289       0.721470    0.764344
# 76      0.806236   0.709804      0.795  0.804948       0.781885    0.829412
# 77      0.742291   0.659491      0.741  0.754967       0.730769    0.780822
# 78      0.746862   0.695906      0.733  0.754370       0.714286    0.799220
# 79      0.746667   0.657534      0.741  0.755891       0.729091    0.784736
#
# [80 rows x 13 columns]

# %% [markdown]
# # Standard Scores 20000

# %%
df20000 = pd.read_csv('../src/performance/testing/standard-scores-20000.csv')

# %%
df20000
# Out:
#     Batch  NB Score     NB F1  NB Precision  NB Recall  PA Score     PA F1  \
# 0       0     0.761  0.759799      0.757515   0.762097     0.738  0.749042
# 1       1     0.755  0.751269      0.741483   0.761317     0.730  0.730539
# 2       2     0.761  0.766829      0.769080   0.764591     0.740  0.753321
# 3       3     0.753  0.747185      0.766807   0.728543     0.719  0.725318
# 4       4     0.786  0.775210      0.778481   0.771967     0.770  0.773622
# ..    ...       ...       ...           ...        ...       ...       ...
# 75     75     0.766  0.760246      0.760246   0.760246     0.736  0.741683
# 76     76     0.780  0.781746      0.791165   0.772549     0.761  0.767736
# 77     77     0.751  0.752731      0.764113   0.741683     0.753  0.765432
# 78     78     0.747  0.756497      0.747148   0.766082     0.736  0.753271
# 79     79     0.741  0.745329      0.749012   0.741683     0.714  0.724470
#
#     PA Precision  PA Recall  SGD Score    SGD F1  SGD Precision  SGD Recall
# 0       0.713504   0.788306      0.752  0.759690       0.731343    0.790323
# 1       0.709302   0.753086      0.742  0.748047       0.711896    0.788066
# 2       0.735185   0.772374      0.756  0.769811       0.747253    0.793774
# 3       0.710728   0.740519      0.749  0.759348       0.730627    0.790419
# 4       0.730483   0.822176      0.774  0.774451       0.740458    0.811715
# ..           ...        ...        ...       ...            ...         ...
# 75      0.709738   0.776639      0.740  0.740519       0.721790    0.760246
# 76      0.761079   0.774510      0.794  0.803059       0.783582    0.823529
# 77      0.743542   0.788650      0.742  0.756144       0.731261    0.782779
# 78      0.723519   0.785575      0.734  0.755064       0.715532    0.799220
# 79      0.713472   0.735812      0.740  0.754717       0.728597    0.782779
#
# [80 rows x 13 columns]

# %% [markdown]
# # Comparisons

# %%
dataSGD = {
    '2500': df2500['SGD F1'].mean(),
    '5000': df5000['SGD F1'].mean(),
    '10000': df10000['SGD F1'].mean(),
    '20000': df20000['SGD F1'].mean()
}
dataSGD
# Out:
# {'2500': 0.7660527192046173,
#  '5000': 0.7660092081225038,
#  '10000': 0.7661456565391325,
#  '20000': 0.7652721349956069}

# %%
batchSizeSGD = dataSGD.keys()
meanSGD = dataSGD.values()
plt.bar(batchSize, meanSGD,width = 0.4)
plt.xlabel("Batch Size")
plt.ylabel("F1 Score in %")
plt.title("Comparison of SGD F1 Score across Batch Size")
plt.show()

# %%
dataNB = {
    '2500': df2500['NB F1'].mean(),
    '5000': df5000['NB F1'].mean(),
    '10000': df10000['NB F1'].mean(),
    '20000': df20000['NB F1'].mean()
}
dataNB
# Out:
# {'2500': 0.765325816397656,
#  '5000': 0.765325816397656,
#  '10000': 0.765325816397656,
#  '20000': 0.765325816397656}

# %%
batchSizeNB = dataNB.keys()
meanNB = dataNB.values()
plt.bar(batchSizeNB, meanNB,width = 0.4)
plt.xlabel("Batch Size")
plt.ylabel("F1 Score in %")
plt.title("Comparison of NB F1 Score across Batch Size")
plt.show()

# %%
dataPA = {
    '2500': df2500['PA F1'].mean(),
    '5000': df5000['PA F1'].mean(),
    '10000': df10000['PA F1'].mean(),
    '20000': df20000['PA F1'].mean()
}
dataPA
# Out:
# {'2500': 0.7359898810044992,
#  '5000': 0.7444449364073336,
#  '10000': 0.7184660770080186,
#  '20000': 0.7425039948960338}

# %%
batchSizePA = dataPA.keys()
meanPA = dataPA.values()
plt.bar(batchSizePA, meanPA,width = 0.4)
plt.xlabel("Batch Size")
plt.ylabel("F1 Score in %")
plt.title("Comparison of PA F1 Score across Batch Size")
plt.show()
